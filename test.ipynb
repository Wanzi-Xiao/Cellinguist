# %%
import scanpy as sc

# %%
adata = sc.read_h5ad("../TestOfLLM_project/03_output/subset_top2000.h5ad")

# %%
adata.var.columns
# Out:
# Index(['vf_vst_counts_mean', 'vf_vst_counts_variance',
#        'vf_vst_counts_variance.expected',
#        'vf_vst_counts_variance.standardized', 'vf_vst_counts_variable',
#        'vf_vst_counts_rank', 'var.features', 'var.features.rank'],
#       dtype='object')

# %%
adata.obs.columns
# Out:
# Index(['orig.ident', 'nCount_RNA', 'nFeature_RNA'], dtype='object')

# %%
adata.obs['orig.ident']
# Out:
# AAACCTGCAAACCTAC-1_1_1_1_1_1_1_1    0
# AAACCTGCACTAGTAC-1_1_1_1_1_1_1_1    0
# AAACCTGGTAAGGGCT-1_1_1_1_1_1_1_1    0
# AAACCTGGTCCAGTGC-1_1_1_1_1_1_1_1    0
# AAACCTGGTCGCTTTC-1_1_1_1_1_1_1_1    0
#                                    ..
# TTTGTCAGTATGGTTC-1_2                0
# TTTGTCAGTCTCTCTG-1_2                0
# TTTGTCAGTTCGCGAC-1_2                0
# TTTGTCATCCGTCATC-1_2                0
# TTTGTCATCGGTTAAC-1_2                0
# Name: orig.ident, Length: 100539, dtype: int32

# %%
adata.var.columns
# Out:
# Index(['vf_vst_counts_mean', 'vf_vst_counts_variance',
#        'vf_vst_counts_variance.expected',
#        'vf_vst_counts_variance.standardized', 'vf_vst_counts_variable',
#        'vf_vst_counts_rank', 'var.features', 'var.features.rank'],
#       dtype='object')

# %%
adata.var.index
# Out:
# Index(['HES4', 'ISG15', 'TNFRSF18', 'TNFRSF4', 'MXRA8', 'VWA1', 'GABRD',
#        'HES5', 'TNFRSF9', 'ERRFI1',
#        ...
#        'ENSG00000283458', 'PELATON', 'CCN5', 'ENSG00000267412',
#        'ENSG00000267328', 'NIBAN3', 'DUXAP8', 'KLHDC7B-DT', 'H1-0',
#        'ENSG00000286129'],
#       dtype='object', length=2000)

# %%
adata.var['index']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/CellLinguistEnv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'index'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 adata.var['index']
#
# ...

# %%
adata.var["var.features"]
# Out:
# HES4                      IGHV3-23
# ISG15                          HBB
# TNFRSF18                  IGKV3-20
# TNFRSF4                    IGKV1-5
# MXRA8                     IGKV3-15
#                         ...
# NIBAN3                      SDF2L1
# DUXAP8                      CYP3A7
# KLHDC7B-DT         ENSG00000257634
# H1-0                       ATP13A5
# ENSG00000286129              INSL4
# Name: var.features, Length: 2000, dtype: object
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
print("X shape:", adata.X.shape)
# Out:
# X shape: (100539, 2000)

# %%
print("Nonzero entries in X:", (adata.X > 0).sum())
# Out:
# Nonzero entries in X: 0

# %%
print(adata.raw)
print("Nonzero entries in adata.raw.X:", (adata.raw.X > 0).sum())
# Out:
# Raw AnnData with n_obs × n_vars = 100539 × 2000
#     var: 'vf_vst_counts_mean', 'vf_vst_counts_variance', 'vf_vst_counts_variance.expected', 'vf_vst_counts_variance.standardized', 'vf_vst_counts_variable', 'vf_vst_counts_rank', 'var.features', 'var.features.rank'
# Nonzero entries in adata.raw.X: 10128078

# %%
import numpy as np
adata.X = adata.raw.X.copy()
adata.X = adata.raw.X.toarray()
adata.write("../TestOfLLM_project/03_output/subset_top2000.h5ad")

# %%
(adata.X > 0).sum()
# Out:
# np.int64(10128078)

# %%
adata = sc.read_h5ad("../TestOfLLM_project/03_output/subset_top2000.h5ad")

# %%
(adata.X > 0).sum()
# Out:
# np.int64(10128078)
